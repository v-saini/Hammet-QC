# %%
# Installing numpy version 1.23. This version is specifically desired for calculating descriptors using Mordred.
# !pip install numpy==1.23
# Out:
# Requirement already satisfied: numpy==1.23 in /usr/local/lib/python3.11/dist-packages (1.23.0)

# %%
import numpy
numpy.__version__
# Out:
# '1.23.0'

# %%
# Installing rdkit and mordred
# !pip install rdkit==2023.09.3
# !pip install mordred
# Out:
# Requirement already satisfied: rdkit==2023.09.3 in /usr/local/lib/python3.11/dist-packages (2023.9.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rdkit==2023.09.3) (1.23.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from rdkit==2023.09.3) (11.1.0)
# Requirement already satisfied: mordred in /usr/local/lib/python3.11/dist-packages (1.2.0)
# Requirement already satisfied: six==1.* in /usr/local/lib/python3.11/dist-packages (from mordred) (1.17.0)
# Requirement already satisfied: numpy==1.* in /usr/local/lib/python3.11/dist-packages (from mordred) (1.23.0)
# Requirement already satisfied: networkx==2.* in /usr/local/lib/python3.11/dist-packages (from mordred) (2.8.8)

# %%
# Importing modules
import rdkit
from rdkit import Chem
from rdkit.Chem import Draw, PandasTools, AllChem

import mordred
from mordred import Calculator, descriptors

import pandas as pd
from tqdm import tqdm
# Out:
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality

# %%
# Loading the raw dataset containing SMILES and Hammett's Sigma constant values
df = pd.read_csv('data.csv')

# %% [markdown]
# ## **Data Generation**

# %%
df.head()
# Out:
#                            SMILES  Sigma
# 0           O=C(O)c1cccc(B(F)F)c1   0.32
# 1              O=C(O)c1cccc(Br)c1   0.39
# 2  O=C(O)c1cccc([Ge](Br)(Br)Br)c1   0.66
# 3  O=C(O)c1cccc([Si](Br)(Br)Br)c1   0.48
# 4              O=C(O)c1cccc(Cl)c1   0.37

# %%
# Generating column containing molecular objects
mol_list = []

for smile in df['SMILES']:
  mol = Chem.MolFromSmiles(smile)
  mol = Chem.AddHs(mol)
  mol_list.append(mol)

df = pd.concat([df, pd.DataFrame(mol_list, columns = (['Mol']))], axis=1)

# %%
# Creating a descriptor calculator with all descriptors
calc_2d = Calculator(descriptors, ignore_3D=True)

# %%
df.head()
# Out:
#                            SMILES  Sigma  \
# 0           O=C(O)c1cccc(B(F)F)c1   0.32
# 1              O=C(O)c1cccc(Br)c1   0.39
# 2  O=C(O)c1cccc([Ge](Br)(Br)Br)c1   0.66
# 3  O=C(O)c1cccc([Si](Br)(Br)Br)c1   0.48
# 4              O=C(O)c1cccc(Cl)c1   0.37
#
#                                                 Mol
# 0  <rdkit.Chem.rdchem.Mol object at 0x7a03a01d5e00>
# 1  <rdkit.Chem.rdchem.Mol object at 0x7a03a01d4900>
# 2  <rdkit.Chem.rdchem.Mol object at 0x7a03a01d5af0>
# 3  <rdkit.Chem.rdchem.Mol object at 0x7a03a01d47b0>
# 4  <rdkit.Chem.rdchem.Mol object at 0x7a03a01d5310>

# %%
# Iterate through molecules
d = []
for mol in tqdm(df['Mol']):
# Calculate descriptors
  result = calc_2d(mol)
  d.append(result)


final_df_2d = pd.concat([df, pd.DataFrame(d, columns = (str(key) for key in result.keys()))], axis=1)
# Out:
# 100%|██████████| 982/982 [01:46<00:00,  9.21it/s]

# %%
final_df_2d.head()
# Out:
#                            SMILES  Sigma  \
# 0           O=C(O)c1cccc(B(F)F)c1   0.32
# 1              O=C(O)c1cccc(Br)c1   0.39
# 2  O=C(O)c1cccc([Ge](Br)(Br)Br)c1   0.66
# 3  O=C(O)c1cccc([Si](Br)(Br)Br)c1   0.48
# 4              O=C(O)c1cccc(Cl)c1   0.37
#
#                                                 Mol       ABC     ABCGG  \
# 0  <rdkit.Chem.rdchem.Mol object at 0x7a03a01d5e00>  8.841960  8.356358
# 1  <rdkit.Chem.rdchem.Mol object at 0x7a03a01d4900>  7.358797  6.989468
# 2  <rdkit.Chem.rdchem.Mol object at 0x7a03a01d5af0>  9.785874  9.203562
# 3  <rdkit.Chem.rdchem.Mol object at 0x7a03a01d47b0>  9.785874  9.203562
# 4  <rdkit.Chem.rdchem.Mol object at 0x7a03a01d5310>  7.358797  6.989468
#
#    nAcid  nBase    SpAbs_A   SpMax_A  SpDiam_A  ...     SRW10     TSRW10  \
# 0      1      0  14.379234  2.288246  4.576491  ...  9.089866  42.251151
# 1      1      0  11.908678  2.242838  4.485676  ...  8.830689  39.160939
# 2      1      0  14.978073  2.344507  4.689013  ...  9.380674  44.214989
# 3      1      0  14.978073  2.344507  4.689013  ...  9.380674  44.214989
# 4      1      0  11.908678  2.242838  4.485676  ...  8.830689  39.160939
#
#            MW        AMW  WPath  WPol  Zagreb1  Zagreb2  mZagreb1  mZagreb2
# 0  170.035066  10.002063    197    15     56.0     62.0  5.444444  2.722222
# 1  199.947292  13.329819    117    11     46.0     50.0  4.333333  2.277778
# 2  431.705144  23.983619    240    17     64.0     71.0  6.395833  2.777778
# 3  385.760892  21.431161    240    17     64.0     71.0  6.395833  2.777778
# 4  155.997807  10.399854    117    11     46.0     50.0  4.333333  2.277778
#
# [5 rows x 1616 columns]

# %%
final_df_2d.drop('Mol', axis=1, inplace=True)

# %% [markdown]
# # **Data Preprocessing**

# %%
final_df_2d_desc = final_df_2d.drop(['Sigma', 'SMILES'], axis=1)

# %%
# Checking for nan vlaues
final_df_2d_desc.isna().sum().sum()
# Out:
# 0

# %%
final_df_2d_desc.head()
# Out:
#         ABC     ABCGG  nAcid  nBase    SpAbs_A   SpMax_A  SpDiam_A     SpAD_A  \
# 0  8.841960  8.356358      1      0  14.379234  2.288246  4.576491  14.379234
# 1  7.358797  6.989468      1      0  11.908678  2.242838  4.485676  11.908678
# 2  9.785874  9.203562      1      0  14.978073  2.344507  4.689013  14.978073
# 3  9.785874  9.203562      1      0  14.978073  2.344507  4.689013  14.978073
# 4  7.358797  6.989468      1      0  11.908678  2.242838  4.485676  11.908678
#
#     SpMAD_A   LogEE_A  ...     SRW10     TSRW10          MW        AMW  WPath  \
# 0  1.198270  3.375790  ...  9.089866  42.251151  170.035066  10.002063    197
# 1  1.190868  3.197246  ...  8.830689  39.160939  199.947292  13.329819    117
# 2  1.152159  3.464600  ...  9.380674  44.214989  431.705144  23.983619    240
# 3  1.152159  3.464600  ...  9.380674  44.214989  385.760892  21.431161    240
# 4  1.190868  3.197246  ...  8.830689  39.160939  155.997807  10.399854    117
#
#    WPol  Zagreb1  Zagreb2  mZagreb1  mZagreb2
# 0    15     56.0     62.0  5.444444  2.722222
# 1    11     46.0     50.0  4.333333  2.277778
# 2    17     64.0     71.0  6.395833  2.777778
# 3    17     64.0     71.0  6.395833  2.777778
# 4    11     46.0     50.0  4.333333  2.277778
#
# [5 rows x 1613 columns]

# %%
# Grabbing only the columns containing numberical and boolean values (True/False)
bool_cols = []
num_cols = []
for col in final_df_2d_desc.columns:
  if final_df_2d_desc[col].dtype == 'object':
    pass
  elif final_df_2d_desc[col].dtype =='bool':
      bool_cols.append(col)
  else:
      num_cols.append(col)

# %%
final_df_2d_desc.shape
# Out:
# (982, 1613)

# %%
# Creating a dataset containing only numerical and boolean columns
final_df_2d_desc_ = final_df_2d_desc[num_cols + bool_cols]

# %%
final_df_2d_desc_.shape
# Out:
# (982, 1336)

# %%
# Defining a function to remove constant values (variance=0) from the dataset
def remove_constant_values(data):
    return [e for e in data.columns if data[e].nunique() == 1]

drop_col = remove_constant_values(final_df_2d_desc_)
#drop_col

new_df_columns = [e for e in final_df_2d_desc_.columns if e not in drop_col]
new_df = final_df_2d_desc_[new_df_columns]
new_df
# Out:
#            ABC      ABCGG  nAcid  nBase    SpAbs_A   SpMax_A  SpDiam_A  \
# 0     8.841960   8.356358      1      0  14.379234  2.288246  4.576491
# 1     7.358797   6.989468      1      0  11.908678  2.242838  4.485676
# 2     9.785874   9.203562      1      0  14.978073  2.344507  4.689013
# 3     9.785874   9.203562      1      0  14.978073  2.344507  4.689013
# 4     7.358797   6.989468      1      0  11.908678  2.242838  4.485676
# ..         ...        ...    ...    ...        ...       ...       ...
# 977  22.620928  17.887780      1      0  38.870645  2.530735  5.061470
# 978  21.852211  17.533757      1      0  37.448307  2.565975  5.131949
# 979  21.852211  17.533757      1      0  37.448307  2.565975  5.131949
# 980  21.852211  17.533757      1      0  37.448307  2.565975  5.131949
# 981  26.098650  19.548378      1      1  44.753186  2.505973  5.011945
#
#         SpAD_A   SpMAD_A   LogEE_A  ...          MW        AMW  WPath  WPol  \
# 0    14.379234  1.198270  3.375790  ...  170.035066  10.002063    197    15
# 1    11.908678  1.190868  3.197246  ...  199.947292  13.329819    117    11
# 2    14.978073  1.152159  3.464600  ...  431.705144  23.983619    240    17
# 3    14.978073  1.152159  3.464600  ...  385.760892  21.431161    240    17
# 4    11.908678  1.190868  3.197246  ...  155.997807  10.399854    117    11
# ..         ...       ...       ...  ...         ...        ...    ...   ...
# 977  38.870645  1.340367  4.300253  ...  397.123166   8.104554   2034    49
# 978  37.448307  1.337440  4.269147  ...  380.123256   7.919235   1767    50
# 979  37.448307  1.337440  4.269147  ...  472.048525   9.834344   1767    50
# 980  37.448307  1.337440  4.269147  ...  364.146330   7.586382   1767    50
# 981  44.753186  1.356157  4.437238  ...  428.164505   7.784809   2908    55
#
#      Zagreb1  Zagreb2  mZagreb1  mZagreb2  Lipinski  GhoseFilter
# 0       56.0     62.0  5.444444  2.722222      True        False
# 1       46.0     50.0  4.333333  2.277778      True        False
# 2       64.0     71.0  6.395833  2.777778      True        False
# 3       64.0     71.0  6.395833  2.777778      True        False
# 4       46.0     50.0  4.333333  2.277778      True        False
# ..       ...      ...       ...       ...       ...          ...
# 977    152.0    181.0  7.729167  6.486111     False         True
# 978    148.0    179.0  7.479167  6.277778      True         True
# 979    148.0    179.0  7.479167  6.277778      True         True
# 980    148.0    179.0  7.479167  6.277778     False        False
# 981    176.0    209.0  8.361111  7.277778     False        False
#
# [982 rows x 1206 columns]

# %%
# Loading the dataset containing quantum chemical descriptors
df_2 = pd.read_csv('data_QC.csv')

# %%
df_2.head(2)
# Out:
#                   SMILES  Sigma  NBO_CC  NBO_SC  E(HOMO)  E(LUMO)
# 0  O=C(O)c1cccc(B(F)F)c1   0.32  -0.183  -0.489 -0.28817 -0.08233
# 1     O=C(O)c1cccc(Br)c1   0.39  -0.162  -0.130 -0.26324 -0.07616

# %%
# Concatanating the two dataset, one with quantum chemical descriptors and other with Mordred descriptors
new_df_ = pd.concat([df_2, new_df], axis=1)
# Dropping SMILES and Sigman columns for further processing
new_df_final = new_df_.drop(['SMILES', 'Sigma'], axis=1)

# %%
new_df_final.shape
# Out:
# (982, 1210)

# %%
# To calclulate  Correlation and remove highly  correlated columns
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
# Dropping highly correlated Features
corr_features = correlation(new_df_final, 0.80)
print("No. of features to drop : ",len(set(corr_features)))

new_df_final.drop(corr_features,axis=1,inplace=True)
# Out:
# No. of features to drop :  927

# %%
new_df_final.shape
# Out:
# (982, 283)

# %%
new_df_final.head(2)
# Out:
#    NBO_CC  NBO_SC  E(HOMO)       ABC  nAcid  nBase   SpMAD_A  nAromAtom  \
# 0  -0.183  -0.489 -0.28817  8.841960      1      0  1.198270          6
# 1  -0.162  -0.130 -0.26324  7.358797      1      0  1.190868          6
#
#    nBridgehead  nHetero  ...      JGI3      JGI4      JGI5  JGI6  JGI7  JGI8  \
# 0            0        5  ...  0.050000  0.049293  0.059028   0.0   0.0   0.0
# 1            0        3  ...  0.056818  0.066032  0.031250   0.0   0.0   0.0
#
#    JGI9  TopoShapeIndex  Lipinski  GhoseFilter
# 0   0.0        1.000000      True        False
# 1   0.0        0.666667      True        False
#
# [2 rows x 283 columns]

# %%
# Converting boolean descriptors to numbers 0s and 1s.
new_df_final['Lipinski'] = new_df_final["Lipinski"].astype(int)
new_df_final['GhoseFilter'] = new_df_final["GhoseFilter"].astype(int)

# %%
new_df_final.head(2)
# Out:
#    NBO_CC  NBO_SC  E(HOMO)       ABC  nAcid  nBase   SpMAD_A  nAromAtom  \
# 0  -0.183  -0.489 -0.28817  8.841960      1      0  1.198270          6
# 1  -0.162  -0.130 -0.26324  7.358797      1      0  1.190868          6
#
#    nBridgehead  nHetero  ...      JGI3      JGI4      JGI5  JGI6  JGI7  JGI8  \
# 0            0        5  ...  0.050000  0.049293  0.059028   0.0   0.0   0.0
# 1            0        3  ...  0.056818  0.066032  0.031250   0.0   0.0   0.0
#
#    JGI9  TopoShapeIndex  Lipinski  GhoseFilter
# 0   0.0        1.000000         1            0
# 1   0.0        0.666667         1            0
#
# [2 rows x 283 columns]

# %%
new_df_final.shape
# Out:
# (982, 283)

# %%
df_2.head()
# Out:
#                            SMILES  Sigma  NBO_CC  NBO_SC  E(HOMO)  E(LUMO)
# 0           O=C(O)c1cccc(B(F)F)c1   0.32  -0.183  -0.489 -0.28817 -0.08233
# 1              O=C(O)c1cccc(Br)c1   0.39  -0.162  -0.130 -0.26324 -0.07616
# 2  O=C(O)c1cccc([Ge](Br)(Br)Br)c1   0.66  -0.169  -0.515 -0.29236 -0.09336
# 3  O=C(O)c1cccc([Si](Br)(Br)Br)c1   0.48  -0.173  -0.577 -0.28562 -0.08182
# 4              O=C(O)c1cccc(Cl)c1   0.37  -0.162  -0.059 -0.26772 -0.07613

# %%
new_df_final_283 = pd.concat([df_2[['SMILES', 'Sigma']], new_df_final], axis=1)

# %%
new_df_final_283.head(2)
# Out:
#                   SMILES  Sigma  NBO_CC  NBO_SC  E(HOMO)       ABC  nAcid  \
# 0  O=C(O)c1cccc(B(F)F)c1   0.32  -0.183  -0.489 -0.28817  8.841960      1
# 1     O=C(O)c1cccc(Br)c1   0.39  -0.162  -0.130 -0.26324  7.358797      1
#
#    nBase   SpMAD_A  nAromAtom  ...      JGI3      JGI4      JGI5  JGI6  JGI7  \
# 0      0  1.198270          6  ...  0.050000  0.049293  0.059028   0.0   0.0
# 1      0  1.190868          6  ...  0.056818  0.066032  0.031250   0.0   0.0
#
#    JGI8  JGI9  TopoShapeIndex  Lipinski  GhoseFilter
# 0   0.0   0.0        1.000000         1            0
# 1   0.0   0.0        0.666667         1            0
#
# [2 rows x 285 columns]

# %%
new_df_final_283.shape
# Out:
# (982, 285)

# %%
# Saving the final dataset as final_data.csv
new_df_final_283.to_csv('final_data.csv', index=None)
